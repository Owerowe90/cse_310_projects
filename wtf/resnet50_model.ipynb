# %%
import os
import pandas as pd
import csv
import matplotlib.pyplot as plotter_lib
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pathlib

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
fish_pics = '/content/gdrive/MyDrive/WTF/fish_data'

# %%
print(fish_pics)
# Out:
# /content/gdrive/MyDrive/WTF/fish_data

# %%
all_brook = list(fish_pics.glob('brook/*'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-4987466f5a7c> in <cell line: 1>()
# ----> 1 all_brook = list(fish_pics.glob('brook/*'))
#
# AttributeError: 'str' object has no attribute 'glob'

# %%
fish_data = tf.keras.utils.get_file('fish_data', origin=fish_pics, untar=True)
fish_data = pathlib.Path(fish_data)
# Out:
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-4493ae53b93c> in <cell line: 1>()
# ----> 1 fish_data = tf.keras.utils.get_file('fish_data', origin=fish_pics, untar=True)
#       2 fish_data = pathlib.Path(fish_data)
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/data_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     344         try:
#     345             try:
# --> 346                 urlretrieve(origin, fpath, DLProgbar())
#     347             except urllib.error.HTTPError as e:
#     348                 raise Exception(error_msg.format(origin, e.code, e.msg))
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/data_utils.py in urlretrieve(url, filename, reporthook, data)
#      83                     break
#      84
# ...
